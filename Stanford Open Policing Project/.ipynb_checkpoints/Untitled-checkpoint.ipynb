# %%
#https://openpolicing.stanford.edu/data/

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime as dt

# %%
rhode_island = pd.read_csv("ri_statewide_2020_04_01.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6,17,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rhode_island.head()
# Out:
#    raw_row_number        date      time zone subject_race subject_sex  \
# 0               1  2005-11-22  11:15:00   X3        white        male
# 1               2  2005-10-01  12:20:00   X3        white        male
# 2               3  2005-10-01  12:30:00   X3        white      female
# 3               4  2005-10-01  12:50:00   X3        white        male
# 4               5  2005-10-01  13:10:00   X3        white      female
#
#   department_id       type arrest_made citation_issued  ... reason_for_stop  \
# 0           200  vehicular       False            True  ...        Speeding
# 1           200  vehicular       False            True  ...        Speeding
# 2           200  vehicular       False            True  ...        Speeding
# 3           200  vehicular       False            True  ...        Speeding
# 4           200  vehicular       False            True  ...        Speeding
#
#   vehicle_make vehicle_model raw_BasisForStop raw_OperatorRace  \
# ...

# %%
rhode_island.shape
# Out:
# (509681, 31)

# %%
rhode_island.isna().sum()
# Out:
# raw_row_number                0
# date                         10
# time                         10
# zone                         10
# subject_race              29073
# subject_sex               29097
# department_id                10
# type                          0
# arrest_made               29073
# citation_issued           29073
# warning_issued            29073
# outcome                   35841
# contraband_found         491919
# contraband_drugs         493693
# contraband_weapons       497886
# contraband_alcohol       508464
# contraband_other         491919
# frisk_performed              10
# search_conducted              0
# search_basis             491919
# reason_for_search        491919
# reason_for_stop           29073
# vehicle_make             191564
# vehicle_model            279593
# raw_BasisForStop          29073
# raw_OperatorRace          29073
# raw_OperatorSex           29073
# raw_ResultOfStop          29073
# raw_SearchResultOne      491919
# ...

# %%
rhode_island.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509681 entries, 0 to 509680
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   raw_row_number         509681 non-null  int64
#  1   date                   509671 non-null  object
#  2   time                   509671 non-null  object
#  3   zone                   509671 non-null  object
#  4   subject_race           480608 non-null  object
#  5   subject_sex            480584 non-null  object
#  6   department_id          509671 non-null  object
#  7   type                   509681 non-null  object
#  8   arrest_made            480608 non-null  object
#  9   citation_issued        480608 non-null  object
#  10  warning_issued         480608 non-null  object
#  11  outcome                473840 non-null  object
#  12  contraband_found       17762 non-null   object
#  13  contraband_drugs       15988 non-null   object
# ...

# %%
rhode_island['zone'].unique()
# Out:
# array(['X3', 'X4', 'K3', 'K2', 'K1', 'X1', nan], dtype=object)

# %%
rhode_island['vehicle_model'].unique()
# Out:
# array([nan, 'HIGHLA', 'TOWN CAR', ..., 'SRT10', 'TL COUPE', 'OTS'],
#       dtype=object)

# %%
rhode_island.arrest_made = rhode_island.arrest_made.astype('bool')

# %%
rhode_island.citation_issued = rhode_island.citation_issued.astype('bool')

# %% [markdown]
# Combine date and time to produce a datetime column.

# %%
rhode_island.head(2)
# Out:
#    raw_row_number        date      time zone subject_race subject_sex  \
# 0               1  2005-11-22  11:15:00   X3        white        male
# 1               2  2005-10-01  12:20:00   X3        white        male
#
#   department_id       type arrest_made citation_issued  ... reason_for_stop  \
# 0           200  vehicular       False            True  ...        Speeding
# 1           200  vehicular       False            True  ...        Speeding
#
#   vehicle_make vehicle_model raw_BasisForStop raw_OperatorRace  \
# 0          NaN           NaN               SP                W
# 1          NaN           NaN               SP                W
#
#   raw_OperatorSex raw_ResultOfStop raw_SearchResultOne  raw_SearchResultTwo  \
# 0               M                M                 NaN                  NaN
# 1               M                M                 NaN                  NaN
#
#   raw_SearchResultThree
# 0                   NaN
# 1                   NaN
#
# ...

# %%
combined = rhode_island.date.str.cat(rhode_island.time, sep=' ')

# %%
rhode_island['date_time'] = pd.to_datetime(combined)

# %%
rhode_island.head(2)
# Out:
#    raw_row_number        date      time zone subject_race subject_sex  \
# 0               1  2005-11-22  11:15:00   X3        white        male
# 1               2  2005-10-01  12:20:00   X3        white        male
#
#   department_id       type arrest_made citation_issued  ... vehicle_make  \
# 0           200  vehicular       False            True  ...          NaN
# 1           200  vehicular       False            True  ...          NaN
#
#   vehicle_model raw_BasisForStop raw_OperatorRace raw_OperatorSex  \
# 0           NaN               SP                W               M
# 1           NaN               SP                W               M
#
#   raw_ResultOfStop raw_SearchResultOne raw_SearchResultTwo  \
# 0                M                 NaN                 NaN
# 1                M                 NaN                 NaN
#
#    raw_SearchResultThree           date_time
# 0                    NaN 2005-11-22 11:15:00
# 1                    NaN 2005-10-01 12:20:00
#
# ...

# %%
rhode_island.date_time.dtype
# Out:
# dtype('<M8[ns]')

# %%
rhode_island.dtypes
# Out:
# zone                     object
# subject_race             object
# subject_sex              object
# department_id            object
# type                     object
# arrest_made                bool
# citation_issued            bool
# warning_issued           object
# outcome                  object
# contraband_found         object
# contraband_drugs         object
# contraband_weapons       object
# contraband_alcohol       object
# contraband_other         object
# frisk_performed          object
# search_conducted           bool
# search_basis             object
# reason_for_search        object
# reason_for_stop          object
# vehicle_make             object
# vehicle_model            object
# raw_BasisForStop         object
# raw_OperatorRace         object
# raw_OperatorSex          object
# raw_ResultOfStop         object
# raw_SearchResultOne      object
# raw_SearchResultTwo      object
# raw_SearchResultThree    object
# dtype: object

# %%
rhode_island.set_index('date_time', inplace = True)

# %%
rhode_island.head(2)
# Out:
#                      raw_row_number        date      time zone subject_race  \
# date_time
# 2005-11-22 11:15:00               1  2005-11-22  11:15:00   X3        white
# 2005-10-01 12:20:00               2  2005-10-01  12:20:00   X3        white
#
#                     subject_sex department_id       type arrest_made  \
# date_time
# 2005-11-22 11:15:00        male           200  vehicular       False
# 2005-10-01 12:20:00        male           200  vehicular       False
#
#                     citation_issued  ... reason_for_stop vehicle_make  \
# date_time                            ...
# 2005-11-22 11:15:00            True  ...        Speeding          NaN
# 2005-10-01 12:20:00            True  ...        Speeding          NaN
#
#                     vehicle_model raw_BasisForStop raw_OperatorRace  \
# date_time
# 2005-11-22 11:15:00           NaN               SP                W
# 2005-10-01 12:20:00           NaN               SP                W
#
# ...

# %%
rhode_island.drop(columns=['date', 'time'], inplace = True, axis = 1)

# %%
rhode_island.drop('raw_row_number', inplace = True, axis = 1)

# %%
rhode_island.head(2)
# Out:
#                     zone subject_race subject_sex department_id       type  \
# date_time
# 2005-11-22 11:15:00   X3        white        male           200  vehicular
# 2005-10-01 12:20:00   X3        white        male           200  vehicular
#
#                     arrest_made citation_issued warning_issued   outcome  \
# date_time
# 2005-11-22 11:15:00       False            True          False  citation
# 2005-10-01 12:20:00       False            True          False  citation
#
#                     contraband_found  ... reason_for_stop vehicle_make  \
# date_time                             ...
# 2005-11-22 11:15:00              NaN  ...        Speeding          NaN
# 2005-10-01 12:20:00              NaN  ...        Speeding          NaN
#
#                     vehicle_model raw_BasisForStop raw_OperatorRace  \
# date_time
# 2005-11-22 11:15:00           NaN               SP                W
# 2005-10-01 12:20:00           NaN               SP                W
#
# ...

# %%
female = rhode_island[rhode_island['subject_sex']=='female']

# %%
male = rhode_island[rhode_island['subject_sex']=='male']

# %%
female.reason_for_stop.value_counts().plot(kind='bar')

# %%
male.reason_for_stop.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
